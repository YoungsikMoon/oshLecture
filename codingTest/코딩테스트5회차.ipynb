# %% [markdown]
# # 문제 1. 나머지가 1이 되는 수 찾기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import time

start = time.time()

def solution(n):
# 답안 작성 부분 ===============




# ==============================
    return answer

end = time.time()

print(solution(10))
print(solution(12))

print("작동시간:", f"{end - start:.5f} sec")

# %% [markdown]
# # 문제 2. 하샤드 수

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import time

start = time.time()

def solution(x):
# 답안 작성 부분 ===============



# ==============================
    return answer

end = time.time()

print(solution(10))
print(solution(12))
print(solution(11))
print(solution(13))

print("작동시간:", f"{end - start:.5f} sec")

# %% [markdown]
# # 문제 3. 행렬의 덧셈

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import time

start = time.time()

def solution(arr1,	arr2):
# 답안 작성 부분 ===============






# ==============================
    return answer

end = time.time()

print(solution([[1,2],[2,3]],	[[3,4],[5,6]]))
print(solution([[1],[2]],	[[3],[4]]))


print("작동시간:", f"{end - start:.5f} sec")

# %% [markdown]
# # 문제 4. 부족한 금액 계산하기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import time

start = time.time()

def solution(price,	money,	count):
# 답안 작성 부분 ===============



# ==============================
    return answer

end = time.time()

print(solution(3,	20,	4))

print("작동시간:", f"{end - start:.5f} sec")

# %% [markdown]
# ## 문제 5. 재미있는 멀티모달(modality) 모델 Study**
#
# #### 아래 CustomModel을 보면, image데이터와 text를 둘다 입력으로 받아 처리한 후 concatenate 하여 최종 분류기에 넣어 클래스를 예측(분류)하는 코드이다. 서로 다른 데이터를 인풋으로 받는 모델, 우린 이걸 멀티모달 모델이라고 한다.
#
#
# #### **문제 설명**:
#
# #### chatGPT, 검색, 오픈북 허용, "# 여기 주석" 이라고 써져있는 곳에 주석을 작성하시오.
#
# #### 주의!) 아래 코드는 안돌아가는 코드. 모델 클래스와 학습 코드만 있을 뿐. 코드를 돌리거나, 완성할 필요가 없다

# %%
import torch.nn as nn

class CustomModel(nn.Module):
    def __init__(self, num_classes):
        super(CustomModel, self).__init__()

        # Image
        self.cnn_extract = nn.Sequential(
            nn.Conv2d(3, 8, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(8, 16, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(32, 64, kernel_size=4, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        # Text
        self.nlp_extract = nn.Sequential(
            nn.Linear(4096, 2048),
            nn.ReLU(),
            nn.Linear(2048, 1024),
        )
        # Classifier
        self.classifier = nn.Sequential(
            nn.Linear(4160, num_classes)
        )

    def forward(self, img, text): # 여기 주석
        img_feature = self.cnn_extract(img) # 여기 주석
        img_feature = torch.flatten(img_feature, start_dim=1) # 여기 주석
        text_feature = self.nlp_extract(text) # 여기 주석
        feature = torch.cat([img_feature, text_feature], axis=1) #여기 주석 (여기가 핵심)
        output = self.classifier(feature) # 여기 주석
        return output

# %%
model = CustomModel(num_classes=10)
model.to(device)
criterion = nn.CrossEntropyLoss().to(device)

epochs = 20
for epoch in range(1, epochs):
    model.train()
    for img, text, label in tqdm(iter(train_loader)): # 여기 주석
        img = img.float().to(device)
        text = text.to(device)
        label = label.to(device)

        optimizer.zero_grad()

        model_pred = model(img, text) # 여기 주석

        loss = criterion(model_pred, label)

        loss.backward()
        optimizer.step()
